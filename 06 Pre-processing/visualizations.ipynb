# %% [markdown]
# # Preamble

# %%
import numpy as np

import matplotlib.pyplot as plt
import math

# %%
X = (np.arange(0, 200, 2) * .1)
mean = 10
sigma = 4
y = [1 / (2*math.pi*sigma**2) * math.exp(-math.pow(x - mean, 2)/(2 * sigma**2)) for x in X]
plt.plot(X, y)

# %%
plt.boxplot(X, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f6ef565d60>,
#   <matplotlib.lines.Line2D at 0x1f6ef566000>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f6ef5662a0>,
#   <matplotlib.lines.Line2D at 0x1f6ef566570>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f6ef565ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f6ef566810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f6ef5669f0>],
#  'means': []}

# %%
X_exp = [math.pow(1.5, t) for t in X]
plt.plot(X_exp, y[:len(X_exp)])

# %%
X_sq = [t**2 for t in X]
plt.plot(X_sq, y)

# %%
plt.boxplot(X_sq, vert = False, showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f6f092ae40>,
#   <matplotlib.lines.Line2D at 0x1f6f09a3470>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f6f09a3710>,
#   <matplotlib.lines.Line2D at 0x1f6f09a39e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f6f09a3050>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f6f09a3c80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f6f09d4260>],
#  'means': [<matplotlib.lines.Line2D at 0x1f6f09a3f50>]}

# %%
X_sqrt = [math.sqrt(t) for t in X]
plt.plot(X_sqrt, y)

# %%
plt.boxplot(X_sqrt, vert = False, showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f6f076da60>,
#   <matplotlib.lines.Line2D at 0x1f6f0950e90>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f6f09523c0>,
#   <matplotlib.lines.Line2D at 0x1f6f0952690>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f6f09520f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f6f0952930>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f6f0952db0>],
#  'means': [<matplotlib.lines.Line2D at 0x1f6f0952b70>]}

# %%
X_log = [math.log(t) for t in X if t > 0]
plt.plot(X_log, y[1:])
